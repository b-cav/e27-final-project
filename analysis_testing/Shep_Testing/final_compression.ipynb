# %%
import heapq 
from collections import Counter

# %% [markdown]
# # Final Project Huffman Compression Code
# ### Regular huffman encoding/decoding

# %%
#################################################################################
#IO Helper functions
#################################################################################
# Reads in a file and returns the text as a string
def readfile(pathname):
    with open(pathname, "r") as f:
        text = f.read()
    return text

# Counts the frequency of each character in a file and returns a dictionary
# Planning on sending in War and Peace txt, which is a large sample of the English language
def count_frequencies(pathname):
    freq = {}
    with open(pathname, "r") as f:
        for char in f.read():
            freq[char] = freq.get(char, 0) + 1
    return freq

# Class for a binary tree node. Holds a character, frequency of that character, and two children
class BTNode:
    def __init__(self, char=None, freq=0):
        self.char = char
        self.freq = freq
        self.left = None
        self.right = None
    # "Magic" function that allows you to use it in a priority queue
    # We are using a min queue so want to pull out lowest frequency first
    def __lt__(self, other):
        return self.freq < other.freq

# Builds the regular huffman tree from a dictionary (freqs) 
# Returns the tree and freqs for easy access
def build_huffman_tree(freqs):
    # Make a priority queue which is heapified by minimum frequency 
    priority_queue = [BTNode(ch, f) for ch, f in freqs.items()]
    heapq.heapify(priority_queue)

    # loop while it is length greater than 1, pulling out two elements and then merging them
    while(len(priority_queue) > 1):
        t1 = heapq.heappop(priority_queue)
        t2 = heapq.heappop(priority_queue)
        tree = BTNode(None, t1.freq + t2.freq) # make new tree with t1 on left, t2 on right
        tree.left = t1
        tree.right = t2
        heapq.heappush(priority_queue, tree) # add the tree back onto the priority queue and loop
    huff_tree = priority_queue[0] # return the the one remaining node, the priority tree
    return huff_tree

# recursively builds the codebook, which maps characters to their codes 
def build_codebook(node, prefix = "", codebook = None):
    if codebook is None: 
        codebook = {}
    if node.char is not None: # Base case: if we are at a leaf, add the 
        codebook[node.char] = prefix
    else:
        build_codebook(node.left, prefix + "0", codebook)
        build_codebook(node.right, prefix + "1", codebook)
    return codebook

# encodes a message given a particular codebook
def encode_message(message, codes):
    encoded_message = "".join(codes[ch] for ch in message) # uses generator expression to create encoded message
    return encoded_message

# decodes a message. Note, requires the huff_tree for decoding
def decode_message(encoded_message, huff_tree):
    result = [] # holds decoded message
    node = huff_tree
    for bit in encoded_message:
        node = node.left if bit == "0" else node.right # go left if 0, go right if 1
        if node.char is not None:  # once you get to leaf
            result.append(node.char)  # add the correct character to the decoded message
            node = huff_tree # start back at the top for next iteration
    decoded_message = "".join(result)
    return decoded_message


# Test regular Huffman tree

freqs = count_frequencies("WarAndPeace.txt") # get frequencies from file

test_text = "hello" 
basic_tree = build_huffman_tree(freqs) # build the huffman tree
basic_codes = build_codebook(basic_tree) # build the codebook
encoded = encode_message(test_text, basic_codes) # encode the test text
decoded = decode_message(encoded, basic_tree) # decode the encoded text
print("Basic Codes:", basic_codes)
print("Message:", test_text)
print("Encoded:", encoded)
print("Decoded:", decoded)
assert decoded == test_text # make sure it works
# Out:
# Basic Codes: {'e': '000', 's': '0010', 'h': '0011', 'i': '0100', 'p': '010100', ',': '010101', ':': '01011000000', '6': '010110000010000', '3': '010110000010001', '/': '0101100000100100', '=': '0101100000100101000', ']': '01011000001001010010', '#': '01011000001001010011', '[': '01011000001001010100', '%': '01011000001001010101', '$': '01011000001001010110', '@': '01011000001001010111', '4': '01011000001001011', '9': '0101100000100110', 'Q': '0101100000100111', 'U': '0101100000101', '*': '0101100000110', 'J': '0101100000111', 'j': '0101100001', 'z': '0101100010', 'q': '0101100011', ';': '01011001000', 'K': '01011001001', 'Y': '01011001010', 'G': '01011001011', 'R': '0101100110', '2': '01011001110000', '0': '01011001110001', 'X': '0101100111001', ')': '010110011101', '(': '010110011110', 'L': '010110011111', 'W': '0101101000', 'S': '0101101001', '-': '010110101', 'P': '010110110', 'A': '010110111', 'y': '010111', 'n': '0110', 'o': '0111', 'l': '10000', 'g': '100010', 'v': '1000110', '?': '1000111000', 'O': '10001110010', '1': '1000111001100', '8': '10001110011010', '7': '1000111001101100', '5': '1000111001101101', 'Z': '100011100110111', 'V': '100011100111', 'T': '100011101', 'M': '1000111100', 'B': '1000111101', 'N': '1000111110', 'C': '10001111110', 'E': '10001111111', 'a': '1001', 't': '1010', 'f': '101100', 'w': '101101', 'd': '10111', ' ': '110', 'm': '111000', 'c': '111001', 'I': '111010000', "'": '111010001', 'x': '1110100100', '!': '1110100101', 'F': '11101001100', 'D': '11101001101', 'H': '1110100111', '.': '1110101', 'u': '111011', '\n': '111100', 'b': '1111010', '"': '11110110', 'k': '11110111', 'r': '11111'}
# Message: hello
# Encoded: 001100010000100000111
# Decoded: hello

# %%
def expected_bits(freqs, codebook):
    total = sum(freqs.values()) # total number of characters
    bits_per_symbol = sum((freqs[s]/total) * len(codebook[s]) for s in freqs) # bits per symbol = sum of prob(s) * length(code(s))
    avg_chars = sum((freqs[s]/total) * (2 if len(s)==2 else 1) for s in freqs) # average originial characters per symbol is key becaus you have more total symbols with bigrams
    return bits_per_symbol / avg_chars # division gives bits per original character


# Identifies the top K bigrams from the text in terms of freqeuncy
def top_bigrams(text, K):
    counts = Counter(text[i:i+2] for i in range(len(text)-1)) # uses Counter package to count occurences of bigrams in text
    return list(bg for bg,_ in counts.most_common(K)) # returns the K most common bigrams as a list
# Computes frequencies of characters and bigrams in the text given a set of bigrams to use
def freqs_with_bigrams(text, bigram_set):
    freqs = Counter()
    i = 0
    N = len(text)
    while i < N:
        if i + 1 < N:
            two = text[i:i+2]
            if two in bigram_set:
                freqs[two] += 1
                i += 2
                continue
        freqs[text[i]] += 1
        i += 1
    return freqs

# %% [markdown]
# ### Test how many bigrams are needed to converge asymptotically using the WarAndPeace text

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
# Computes the expected bits per character

# Plots the expected bits per original character as a function of K, the number of top bigrams used
# Uses the text to compute frequencies with the top K bigrams included
def experiment_plot(text, K_values, sample_every=1):
    """
    text: input string
    K_values: iterable of K values (increasing ints) to evaluate
    sample_every: only evaluate every sample_every-th K to speed up (optional)
    """
    Ks = []
    bits = []

    # precompute a big list of top bigrams up to max K needed
    K_max = max(K_values)
    bigram_list = top_bigrams(text, K_max)

    current_set = set()
    # We'll add bigrams incrementally so we don't rebuild sets from scratch each iteration
    for i, bg in enumerate(bigram_list, start=1):
        current_set.add(bg)
        if i not in K_values:
            continue
        # compute freqs with current bigrams

        freqs = freqs_with_bigrams(text, current_set)
        # build Huffman and codebook (use your implementations)
        tree = build_huffman_tree(freqs)
        codebook = build_codebook(tree)
        # compute expected bits per original character
        bpc = expected_bits(freqs, codebook)
        Ks.append(i)
        bits.append(bpc)

    plt.figure(figsize=(8,5))
    plt.plot(Ks, bits, marker='.')
    plt.xlabel("K (number of top bigrams used)")
    plt.ylabel("Expected bits per original character")
    plt.title("Effect of Top-K bigrams on Huffman coding")
    plt.grid(True)
    plt.show()

text = readfile("WarAndPeace.txt")
# K_values = list(range(1, 1001))   # evaluate every K from 1..1000
# experiment_plot(text, K_values)

K_values = sorted(set([1] + list(np.linspace(1, 1000, 200, dtype=int))))
experiment_plot(text, K_values)

# %% [markdown]
# From this, we concluded that we need around 800-1000 bigrams in our huffman tree to achieve saturating benefit to the expected bits per original character.
#
# # Compare the number of bits used to send the test_message when using the bigram tree compared to the Huffman tree

# %%
# walks through the text and returns a list of symbols ready for Huffman counting to make into a tree
# importnt note: overlapping bigrams are always given priority on the left (ex: for the, th is picked over he)
def replace_bigrams(text, bigram_list):
    out = []
    i = 0
    while i < len(text):
        if i+1 < len(text) and text[i:i+2] in bigram_list: # look at next 2 elements, if in bigram list, add that combination to list
            out.append(text[i:i+2])
            i += 2
        else: # else, just add the character normally
            out.append(text[i])
            i += 1
    return out

# Create bigram tree and codebook
text = readfile("WarAndPeace.txt") 
K = 1000
bigram_list = top_bigrams(text, K)
freqs = Counter(replace_bigrams(text, bigram_list))
bigram_tree = build_huffman_tree(freqs)
bigram_codebook = build_codebook(bigram_tree)

# Test bigram Huffman tree
test_text = readfile("test_message.txt")
encoded_bigram = encode_message(replace_bigrams(test_text, bigram_list), bigram_codebook)
print("Encoded with bigrams:", len(encoded_bigram))
decoded_bigram = decode_message(encoded_bigram, bigram_tree)

assert decoded_bigram == test_text, "Bigram Decoding did not match original!"
# Test regular Huffman tree
freqs = count_frequencies("WarAndPeace.txt")
basic_tree = build_huffman_tree(freqs)
basic_codes = build_codebook(basic_tree)
encoded = encode_message(test_text, basic_codes)
print("Encoded regular:", len(encoded))
decoded = decode_message(encoded, basic_tree)
assert decoded == test_text, "Basic Decoding did not match original!"
# Out:
# Encoded with bigrams: 34271
# Encoded regular: 38206

# %% [markdown]
# From the statistical analysis, we found that there is a penalty for having more bit flips in a message. Our first idea was a very simple technique called differential encoding. The final Huffman-compressed message is encoded with the diff_encode method before being sent across the noisy channel. The encoded message has only one bit of overhead compared to the original message. The receiver must decode the message before error correcting and decompressing

# %%
import unittest
import random
# encodes a bit string using differential encoding, reducing the number of bit flips
def diff_encode(bits, start_prev_bit=0):
    out = []
    prev = start_prev_bit
    for ch in bits:
        b = 1 if ch == "1" else 0
        d = b ^ prev
        out.append("1" if d == 1 else "0")
        prev = b
    return "".join(out)
# decodes a bit string that was encoded using differential encoding
def diff_decode(diffs, start_prev_bit=0):
    out = []
    prev = start_prev_bit
    for ch in diffs:
        d = 1 if ch == "1" else 0
        b = d ^ prev
        out.append("1" if b == 1 else "0")
        prev = b
    return "".join(out)

def encode_with_diff(message, codes, start_prev_bit=0):
    bits = encode_message(message, codes)
    # Optionally choose start_prev_bit to match the first bit to avoid initial flip
    return diff_encode(bits, start_prev_bit=start_prev_bit)

def decode_with_diff(encoded_diffs, tree, start_prev_bit=0):
    bits = diff_decode(encoded_diffs, start_prev_bit=start_prev_bit)
    return decode_message(bits, tree)
# counts the number of bit flips in a bit string
def count_bit_flips(bits):
    return sum(b1 != b2 for b1, b2 in zip(bits, bits[1:]))
#Test differential encoding
test_bits = "11111111111111111000000000000000000"
encoded_diffs = diff_encode(test_bits)
print("Original bits: ", test_bits)
print("number of bit flips in original:", count_bit_flips(test_bits))
print("Diff encoded:  ", encoded_diffs)
print("number of bit flips in encoded: ", count_bit_flips(encoded_diffs))
decoded_bits = diff_decode(encoded_diffs)
print("Diff decoded:  ", decoded_bits)
assert decoded_bits == test_bits, "Diff Decoding did not match original!"

test_cases = [
    "00000000", # no improvement compared to original
    "11111111", # no improvement compared to original
    "10101010", # maximum improvement, 7 flips to 1 flip
    "00000001", # only 1 flip, no improvement
    "111000111000",
    "".join(random.choice("01") for _ in range(50)),  # random, usually some improvement
    ""
]

for bits in test_cases:
    enc = diff_encode(bits)
    dec = diff_decode(enc)
    print(f"Original: {bits}")
    print(f"Encoded : {enc}")
    print(f"Decoded : {dec}")
    print(f"Flips before: {count_bit_flips(bits)}, after: {count_bit_flips(enc)}")
    assert dec == bits, "Mismatch in encode→decode!"
    print("-"*40)
# Out:
# Original bits:  11111111111111111000000000000000000
# number of bit flips in original: 1
# Diff encoded:   10000000000000000100000000000000000
# number of bit flips in encoded:  3
# Diff decoded:   11111111111111111000000000000000000
# Original: 00000000
# Encoded : 00000000
# Decoded : 00000000
# Flips before: 0, after: 0
# ----------------------------------------
# Original: 11111111
# Encoded : 10000000
# Decoded : 11111111
# Flips before: 0, after: 1
# ----------------------------------------
# Original: 10101010
# Encoded : 11111111
# Decoded : 10101010
# Flips before: 7, after: 0
# ----------------------------------------
# Original: 00000001
# Encoded : 00000001
# Decoded : 00000001
# Flips before: 1, after: 1
# ----------------------------------------
# Original: 111000111000
# Encoded : 100100100100
# Decoded : 111000111000
# Flips before: 3, after: 7
# ----------------------------------------
# Original: 00101011100100010010001011100011011011111101001100
# Encoded : 00111110010110011011001110010010110110000011101010
# Decoded : 00101011100100010010001011100011011011111101001100
# Flips before: 26, after: 26
# ----------------------------------------
# Original:
# Encoded :
# Decoded :
# Flips before: 0, after: 0
# ----------------------------------------

# %% [markdown]
# After proving that it works conceptually, I wanted to get some data to show whethe, on average, the message sent has fewer bitflips. I first tried doing trials with random bits, but found that the improvement was not very effective.
#
# Things to write about:
# - default is a 0 percent mean reduction, 0 std reducion
# - mean reduction is worst at 25% when only sending 2 bits. You are always increasing standard deviation of the reduction of number of bit flips with this method
# - as you increase the number of bit bits, std gets worse, but then starts improving.
# - at very high number of bits, you hardly have any improvement

# %%
import numpy as np
def bit_flip_test(num_bits, num_trials=1000):
    reductions = []
    for _ in range(num_trials):
        bits = "".join(random.choice("01") for _ in range(num_bits)) # random string of bits 
        enc = diff_encode(bits) # encode with differential encoding
    # count bit flips before and after 
        flips_before = count_bit_flips(bits)
        flips_after = count_bit_flips(enc)
        if flips_before > 0:
            reduction = (flips_before - flips_after) / flips_before
            reductions.append(reduction)
        else:
            reductions.append(0.0)  # No flips to reduce
    mean_reduction = np.mean(reductions)*100
    std_reduction = np.std(reductions)*100
    print(f"Over {num_trials} trials of {num_bits} random bits:")
    print(f"Mean reduction in bit flips: {mean_reduction}%")
    print(f"Stddev of reduction in bit flips: {std_reduction}%")

bit_flip_test(2, 1000)
bit_flip_test(3, 1000)
bit_flip_test(4, 1000)
bit_flip_test(8, 1000)
bit_flip_test(16, 1000)
bit_flip_test(32, 1000)
bit_flip_test(100, 1000)
# Out:
# Over 1000 trials of 2 random bits:
# Mean reduction in bit flips: 24.4%
# Stddev of reduction in bit flips: 42.94927240361587%
# Over 1000 trials of 3 random bits:
# Mean reduction in bit flips: -7.1499999999999995%
# Stddev of reduction in bit flips: 64.58620208682346%
# Over 1000 trials of 4 random bits:
# Mean reduction in bit flips: -16.633333333333333%
# Stddev of reduction in bit flips: 75.86903189048876%
# Over 1000 trials of 8 random bits:
# Mean reduction in bit flips: -14.61357142857143%
# Stddev of reduction in bit flips: 59.74395522084923%
# Over 1000 trials of 16 random bits:
# Mean reduction in bit flips: -8.221502664002665%
# Stddev of reduction in bit flips: 38.79950755626957%
# Over 1000 trials of 32 random bits:
# Mean reduction in bit flips: -4.182349392971785%
# Stddev of reduction in bit flips: 25.555368804060137%
# Over 1000 trials of 100 random bits:
# Mean reduction in bit flips: -1.206372498683847%
# Stddev of reduction in bit flips: 14.486564013440917%

# %% [markdown]
# Seeing as that idea did not work very well because it increased the standard deviation significantly, I decided to go back to the actual Huffman encoding in the hopes that I could modify it to provide a message with fewer bit flips. I tried out an idea called variable Huffman encoding

# %%
def make_expanded_freqs(freqs, symbols_to_duplicate, num_variants=2):
    """
    Create a new frequency dict where each symbol in symbols_to_duplicate
    is split into num_variants pseudo-symbols with roughly-even counts.
    Others are kept as-is.
    """
    new_freqs = {}
    for sym, cnt in freqs.items():
        if sym in symbols_to_duplicate:
            base = cnt // num_variants # floor division
            rem = cnt % num_variants
            # distribute remainder to first variants
            for v in range(num_variants):
                new_freqs[f"{sym}#{v}"] = base + (1 if v < rem else 0)
        else:
            new_freqs[sym] = cnt
    return new_freqs

def build_codebook_and_decode_map_from_freqs(freqs_expanded):
    """
    Build Huffman tree and codebook using your build_huffman_tree / build_codebook.
    Return:
      - codebook_expanded: symbol -> code (includes variants like 'th#0')
      - decode_map_variant_to_symbol: variant_symbol -> original_symbol (strip '#v')
      - expanded_tree: the Huffman tree returned by your build_huffman_tree (so you can decode with decode_message)
    Note: this assumes your build_huffman_tree returns a tree object compatible with build_codebook.
    """
    expanded_tree = build_huffman_tree(freqs_expanded)
    codebook_expanded = build_codebook(expanded_tree)
    decode_map_variant_to_symbol = {var: var.split("#")[0] for var in codebook_expanded} 
    return codebook_expanded, decode_map_variant_to_symbol, expanded_tree

def precompute_variant_stats(codebook_expanded):
    """
    For each variant symbol compute:
      - code (string)
      - internal_flips (number of 0↔1 inside the codeword)
      - start_bit (0/1)
      - end_bit (0/1)
    Returns dict variant -> stats.
    """
    stats = {}
    for var, code in codebook_expanded.items():
        if len(code) == 0:
            internal = 0
            start = 0
            end = 0
        else:
            internal = sum(1 for i in range(len(code)-1) if code[i] != code[i+1])
            start = int(code[0])
            end = int(code[-1])
        stats[var] = {"code": code, "internal": internal, "start": start, "end": end}
    return stats

def encode_with_variants(text, top_bigrams_list, variant_stats, num_variants=2):
    """
    Encode the original text, choosing among variants greedily to minimize flips.
    Uses same replacement logic as replace_bigrams (give precedence to bigrams).
    Returns encoded bitstring and also list of chosen variant symbols (for debugging).
    """
    i = 0
    prev_end = None
    out_bits = []
    chosen_variants = []
    while i < len(text):
        # choose symbol exactly as replace_bigrams (left-priority), bigrams first
        if i+1 < len(text) and text[i:i+2] in top_bigrams_list:
            sym = text[i:i+2]
            i += 2
        else:
            sym = text[i]
            i += 1
        # find variants available (e.g., "th#0", "th#1"), else plain symbol
        variants = [v for v in variant_stats if v.startswith(sym + "#")]
        if not variants:
            # symbol has no variants; use its single variant name equal to the symbol
            variants = [sym] if sym in variant_stats else []
        # pick best variant greedily
        best = None
        best_cost = None
        for v in variants:
            s = variant_stats[v]
            cost = s["internal"]
            # add cost for boundary flip between prev_end and this start
            if prev_end is not None and prev_end != s["start"]:
                cost += 1
            if best is None or cost < best_cost:
                best = v
                best_cost = cost
        if best is None:
            # fallback: symbol had no entry in variant_stats (shouldn't happen if built consistently)
            raise ValueError("No variant found for symbol: " + sym)
        out_bits.append(variant_stats[best]["code"])
        chosen_variants.append(best)
        prev_end = variant_stats[best]["end"]
    bitstring = "".join(out_bits)
    return bitstring, chosen_variants

def decode_expanded_bitstring_with_tree(bitstring, expanded_tree):
    """
    Decode using your existing decode_message function: it expects a bit string and the Huffman tree
    built over the expanded alphabet. decode_message will return the sequence of variant symbols;
    then map each variant symbol back to original by splitting on '#'.
    """
    decoded_variants = decode_message(bitstring, expanded_tree)
    # decoded_variants is a concatenation of variant symbols (but your decode_message returns characters
    # based on leaves; if leaves are 'th#0' that entire string will be appended as one symbol — this
    # only works if your Huffman alphabet uses symbols that are single python items rather than multiple chars).
    # In the notebook you used multi-character symbols like 'th', so decode_message will append 'th#0' where appropriate.
    # Now map each variant back to original symbol:
    # We need to reconstruct the original text from the list of decoded leaves.
    # The decoded_variants returned as a string must be split back into symbols.
    # If decode_message returns a list-like join, you might already get symbols in a list; adjust accordingly.
    # Here assume decode_message returns a concatenation of symbols; to be safe, better to modify decode_message to
    # append entire leaf strings (your decode_message does `result.append(node.char)` and then joins -> so node.char should be exact symbol).
    # So decoded_message will be the original message if node.char equals original symbols (including bigrams).
    # For variant symbols we must strip variant suffix.
    # Implement mapping below:
    mapped = []
    # If decode_message returned a full string composed of symbols (where symbol can be multiple chars),
    # we need to recover the individual leaf symbols. In your notebook decode_message appends node.char
    # and then join -> so the decoded result is the concatenation of node.char items; we can't split safely here.
    # Therefore, better to use decode_message on the expanded_tree and rely on node.char being exact variant symbol,
    # and that decode_message returns the joined string of those variant symbols concatenated — which *is* the original text
    # but with '#v' suffices included. We'll simply remove the '#v' suffixes from the decoded string wherever present.
    s = decoded_variants
    # Remove variant suffixes: replace occurrences of '#0' '#1' etc.
    for v in range(10):  # safe up to 10 variants
        s = s.replace(f"#{v}", "")
    return s

# -----------------------
# Example workflow (drop into your notebook, after text/freqs are available)
# -----------------------
# 1) Build freqs with your replace_bigrams or count_frequencies approach
text = readfile("test_message.txt")  # use a training slice to speed up (optional)
# build full freqs over hybrid alphabet used in your notebook:
K = 1000
bigram_list = top_bigrams(text, K)  # uses your top_bigrams function
symbols_list = replace_bigrams(text, bigram_list)  # returns list of symbols (same function present)
freqs = Counter(symbols_list)

# 2) pick top M symbols (could be from freqs directly). Choose M reasonably (e.g., 50)
M = 50
top_symbols = set([s for s,_ in freqs.most_common(M)])

# 3) Create expanded freqs by duplicating chosen symbols into two pseudo-symbols
freqs_expanded = make_expanded_freqs(freqs, top_symbols, num_variants=2)

# 4) Build Huffman codebook and expanded tree using your existing build_huffman_tree/build_codebook
codebook_expanded, decode_map_variant_to_symbol, expanded_tree = build_codebook_and_decode_map_from_freqs(freqs_expanded)

# 5) Precompute variant stats
variant_stats = precompute_variant_stats(codebook_expanded)

# 6) Encode test_message.txt using greedy variant selection
test_text = readfile("test_message.txt")
encoded_bits, chosen_vars = encode_with_variants(test_text, bigram_list, variant_stats, num_variants=2)

# 7) Decode with your existing decode_message by supplying expanded_tree
#    (this will return a sequence of leaf node.char strings; then strip '#v' suffixes)
decoded_back = decode_message(encoded_bits, expanded_tree)
# strip suffixes '#0','#1' etc to get original message
for v in range(10):
    decoded_back = decoded_back.replace(f"#{v}", "")

# 8) Evaluate transitions and correctness
print("Encoded length:", len(encoded_bits))
print("Transitions:", count_bit_flips(encoded_bits))
print("Decoded equals original?", decoded_back == test_text)
# Out:
# Encoded length: 35493
# Transitions: 16317
# Decoded equals original? True

# %% [markdown]
# I had Chat GPT create me a test that had parameters that I could tweak so I could see the effect

# %%
# Parameters
NUM_TRIALS = 100
MSG_LEN = 1000   # chars per sampled message
M = 20           # number of top symbols to duplicate (matches your example)
NUM_VARIANTS = 2

# 0) Ensure we have a training text variable; use WarAndPeace or test_message as appropriate
train_text = readfile("WarAndPeace.txt")  # or reuse 'text' if you set it earlier

# 1) Build bigram list and symbol stream like your notebook
K = 1000
bigram_list = top_bigrams(train_text, K)
symbol_list = replace_bigrams(train_text, bigram_list)
freqs = Counter(symbol_list)

# 2) Build regular bigram Huffman once (baseline)
basic_tree = build_huffman_tree(freqs)
basic_codebook = build_codebook(basic_tree)
# sanity check: find any symbols in the training stream missing from the basic_codebook
missing = set()
for sym in set(replace_bigrams(train_text, bigram_list)):
    if sym not in basic_codebook:
        missing.add(sym)
if(not missing): # set empty
    print("Missing symbols in basic_codebook (should be empty):", missing)
# 3) Pick top-M symbols from freqs and make expanded freqs (uses your function)
top_symbols = set(s for s,_ in freqs.most_common(M))
freqs_expanded = make_expanded_freqs(freqs, top_symbols, num_variants=NUM_VARIANTS)

# 4) Build expanded codebook + tree (uses your function)
codebook_expanded, decode_map_variant_to_symbol, expanded_tree = build_codebook_and_decode_map_from_freqs(freqs_expanded)

# 5) Precompute variant stats (uses your function)
variant_stats = precompute_variant_stats(codebook_expanded)

# 6) Helper encoders
# Regular bigram encoder: use your encode_message on the replace_bigrams output (list of symbols)
def encode_regular_bigram(text):
    sym_list = replace_bigrams(text, bigram_list)  # list of symbols
    return encode_message(sym_list, basic_codebook)

# Variant encoder: use your encode_with_variants (which returns bitstring, chosen variants)
def encode_variant_greedy(text):
    bits, chosen = encode_with_variants(text, bigram_list, variant_stats, num_variants=NUM_VARIANTS)
    return bits

# 7) Sampling helper: random substring from train_text
def sample_random_message(length):
    if length >= len(train_text):
        return train_text
    start = random.randrange(0, len(train_text) - length)
    return train_text[start:start+length]

def make_expanded_freqs_skewed(freqs, symbols_to_duplicate, num_variants=2, alpha=0.7):
    """
    Like make_expanded_freqs, but splits counts unevenly to encourage variant codes
    with different leading bits. For num_variants=2, uses fractions alpha and (1-alpha).
    """
    new_freqs = {}
    for sym, cnt in freqs.items():
        if sym in symbols_to_duplicate and num_variants == 2:
            c0 = max(1, int(round(cnt * alpha)))
            c1 = max(1, cnt - c0)
            # adjust if rounding pushed sum off
            if c0 + c1 != cnt:
                c1 += (cnt - (c0 + c1))
            new_freqs[f"{sym}#0"] = c0
            new_freqs[f"{sym}#1"] = c1
        elif sym in symbols_to_duplicate:
            # general case: mildly decreasing weights to diversify codes
            total_w = sum(range(1, num_variants + 1))
            parts = []
            remaining = cnt
            for idx in range(num_variants, 0, -1):
                share = max(1, (cnt * idx) // total_w)
                parts.append(share)
                remaining -= share
            parts[0] += remaining  # fix rounding
            for v, share in enumerate(parts):
                new_freqs[f"{sym}#{v}"] = share
        else:
            new_freqs[sym] = cnt
    return new_freqs

# Use the skewed split instead of the even split:
freqs_expanded = make_expanded_freqs_skewed(freqs, top_symbols, num_variants=NUM_VARIANTS, alpha=0.57)
codebook_expanded, decode_map_variant_to_symbol, expanded_tree = build_codebook_and_decode_map_from_freqs(freqs_expanded)
variant_stats = precompute_variant_stats(codebook_expanded)

# 8) Run trials
reductions = []
reg_transitions = []
var_transitions = []
reg_bits = []
var_bits = []
orig_chars = []
for ti in range(NUM_TRIALS):
    msg = sample_random_message(MSG_LEN)
    # baseline encoding
    enc_reg = encode_regular_bigram(msg)
    t_reg = count_bit_flips(enc_reg)
    # variant encoding
    enc_var = encode_variant_greedy(msg)
    t_var = count_bit_flips(enc_var)
    
    # lengths
    orig_chars.append(len(msg))
    reg_bits.append(len(enc_reg))
    var_bits.append(len(enc_var))

    # transitions
    reg_transitions.append(t_reg)
    var_transitions.append(t_var)

    # reduction percentage
    if t_reg == 0:
        reductions.append(0.0)
    else:
        reductions.append((t_reg - t_var) / t_reg * 100.0)

    # # For each trial print how it did
    # print(f"Trial{ti+1}: orig_chars={len(msg)}, "
    #       f"reg_bits={len(enc_reg)}, var_bits={len(enc_var)}, "
    #       f"reg_bpc={len(enc_reg)/len(msg):.3f}, var_bpc={len(enc_var)/len(msg):.3f}, "
    #       )

# 9) Report results
mean_red = float(np.mean(reductions))
std_red = float(np.std(reductions))
reg_bits_mean = float(np.mean(reg_bits))
var_bits_mean = float(np.mean(var_bits))
reg_bpc_mean = float(np.mean(np.array(reg_bits) / np.array(orig_chars)))
var_bpc_mean = float(np.mean(np.array(var_bits) / np.array(orig_chars)))
print(f"Trials={NUM_TRIALS}, msg_len={MSG_LEN}, duplicated_topM={M}, num_variants={NUM_VARIANTS}")
print(f"Mean reduction in transitions: {mean_red:.4f}%")
print(f"Std  reduction in transitions: {std_red:.4f}%")
print(f"Avg baseline transitions: {np.mean(reg_transitions):.2f}, avg variant transitions: {np.mean(var_transitions):.2f}")

print(f"Mean encoded length (bits: regular={reg_bits_mean:.1f}, variant={var_bits_mean:.1f}), "
      f"delta={reg_bits_mean - var_bits_mean:.1f} bits")
print(f"Mean bits/char (regular={reg_bpc_mean:.4f}, variant={var_bpc_mean:.4f}), "
      f"delta={reg_bpc_mean - var_bpc_mean:.4f} bits/char")
# Out:
# Missing symbols in basic_codebook (should be empty): set()
# Trials=100, msg_len=1000, duplicated_topM=20, num_variants=2
# Mean reduction in transitions: 3.3107%
# Std  reduction in transitions: 1.7352%
# Avg baseline transitions: 2005.27, avg variant transitions: 1938.66
# Mean encoded length (bits: regular=4011.4, variant=4164.3), delta=-152.9 bits
# Mean bits/char (regular=4.0114, variant=4.1643), delta=-0.1529 bits/char

# %% [markdown]
# By tweaking the numbers, I found that the variant Huffman scheme expandeds the code alphabet too much, which leads to an increase in the bits per character. I was not equipped with the tools to judge the tradeoff between the reduced number of transitions and the increased bits per character.
#
# After coming to this conclusion, I decided to pursue a different strategy that preserved the same number of codes, but minimizes the transitions by:
# - Assigning frequent symbols codewords with fewer internal alternations.
# - Aligning end/start bits (via local swaps) to reduce boundary mismatches according to your empirical adjacency.

# %%
from collections import defaultdict, Counter

# 1) Build adjacency counts on the same symbol stream you used for freqs
def adjacency_counts(symbols):
    adj = defaultdict(Counter)
    for a, b in zip(symbols, symbols[1:]):
        adj[a][b] += 1
    return adj

# 2) Helpers to inspect codewords
def code_props(code):
    if not code:
        return 0, 0, 0
    start = int(code[0])
    end = int(code[-1])
    internal = sum(1 for i in range(len(code)-1) if code[i] != code[i+1])
    return start, end, internal

def precompute_code_props(codebook):
    props = {}
    for sym, code in codebook.items():
        s, e, internal = code_props(code)
        props[sym] = {'code': code, 'start': s, 'end': e, 'internal': internal, 'len': len(code)}
    return props

# 3) Cost function: sum of internal flips + lambda * boundary flips (expected)
#    - freqs: symbol -> count
#    - adj: adj[a][b] is count of a followed by b
def total_flip_cost(code_props_by_sym, freqs, adj, lam=1.0):
    # Internal flips
    internal_cost = 0
    for s, f in freqs.items():
        internal_cost += f * code_props_by_sym[s]['internal']
    # Boundary flips
    # boundary flip when end(a) != start(b)
    boundary_cost = 0
    for a, row in adj.items():
        a_end = code_props_by_sym[a]['end']
        for b, cnt in row.items():
            b_start = code_props_by_sym[b]['start']
            boundary_cost += cnt * (1 if a_end != b_start else 0)
    return internal_cost + lam * boundary_cost

# 4) Build a prefix trie over the codebook and list internal prefixes we can swap at.
#    Swapping at prefix p flips the next bit (0<->1) for all codes under p.
def build_prefix_trie(codebook):
    trie = {'children': {}, 'leaf': None}
    for sym, code in codebook.items():
        node = trie
        for ch in code:
            if ch not in node['children']:
                node['children'][ch] = {'children': {}, 'leaf': None}
            node = node['children'][ch]
        node['leaf'] = sym
    return trie

def collect_swappable_prefixes(trie, prefix="", out=None):
    if out is None:
        out = []
    # Internal node if it has at least one child; in Huffman, it should be two children for prefix-free completeness.
    children = trie['children']
    if '0' in children and '1' in children:
        out.append(prefix)  # can swap the next bit under this prefix
    # Recurse
    for bit, child in children.items():
        collect_swappable_prefixes(child, prefix + bit, out)
    return out

def swap_at_prefix(codebook, prefix):
    plen = len(prefix)
    new_cb = {}
    for sym, code in codebook.items():
        if code.startswith(prefix):
            # flip the bit right after prefix
            if len(code) == plen:
                # precaution: a leaf exactly at prefix (rare in canonical Huffman); skip swapping this one
                new_cb[sym] = code
            else:
                bit = code[plen]
                flipped = '1' if bit == '0' else '0'
                new_cb[sym] = code[:plen] + flipped + code[plen+1:]
        else:
            new_cb[sym] = code
    return new_cb

# 5) Optimize by iterative local swaps
def optimize_codebook_for_flips(codebook, freqs, adj, lam=1.0, max_passes=5, verbose=True):
    cb = dict(codebook)  # copy
    props = precompute_code_props(cb)
    base_cost = total_flip_cost(props, freqs, adj, lam=lam)
    if verbose:
        print(f"Initial flip-cost: {base_cost:.2f}")
    for p in range(max_passes):
        trie = build_prefix_trie(cb)
        prefixes = collect_swappable_prefixes(trie)
        improved = False
        # Try each swap greedily; accept if it helps, then continue in the same pass
        for pref in prefixes:
            cand_cb = swap_at_prefix(cb, pref)
            cand_props = precompute_code_props(cand_cb)
            cand_cost = total_flip_cost(cand_props, freqs, adj, lam=lam)
            if cand_cost < base_cost - 1e-9:
                cb = cand_cb
                props = cand_props
                base_cost = cand_cost
                improved = True
                if verbose:
                    print(f"  pass {p+1}: accepted swap at prefix '{pref}', new cost={base_cost:.2f}")
        if not improved:
            if verbose:
                print(f"No improvement in pass {p+1}; stopping.")
            break
    return cb

# 6) Optional: build a decoder from the optimized codebook
def build_decoder_from_codebook(codebook):
    dec = {}
    for sym, code in codebook.items():
        node = dec
        for ch in code:
            node = node.setdefault(ch, {})
        node['$'] = sym  # termination
    return dec

def decode_with_decoder(bits, dec):
    out = []
    node = dec
    for ch in bits:
        node = node[ch]
        if '$' in node:
            out.append(node['$'])
            node = dec
    return out

# Build your baseline on bigram-replaced symbol stream
train_text = readfile("WarAndPeace.txt")
K = 1000
bigram_list = top_bigrams(train_text, K)
symbol_stream = replace_bigrams(train_text, bigram_list)
freqs = Counter(symbol_stream)

# Baseline Huffman (no variants)
basic_tree = build_huffman_tree(freqs)
basic_codebook = build_codebook(basic_tree)

# Compute adjacency on the same symbol stream
adj = adjacency_counts(symbol_stream)

# Optimize codebook for fewer flips; tune lam to trade internal vs boundary flips (start with lam=1.0)
opt_codebook = optimize_codebook_for_flips(basic_codebook, freqs, adj, lam=1.0, max_passes=5, verbose=True)

# Encoder with optimized codebook (bits/char is identical to baseline because lengths unchanged)
def encode_regular_bigram_optimized(text):
    sym_list = replace_bigrams(text, bigram_list)
    return encode_message(sym_list, opt_codebook)

# Optional decoder that doesn't need the original tree
opt_decoder = build_decoder_from_codebook(opt_codebook)
def decode_optimized(bits):
    syms = decode_with_decoder(bits, opt_decoder)  # list of symbols (unigrams/bigrams)
    return "".join(syms)

# Evaluate
NUM_TRIALS = 100
MSG_LEN = 1000
reductions = []
reg_transitions = []
opt_transitions = []
reg_bits = []
opt_bits = []
orig_chars = []

for ti in range(NUM_TRIALS):
    msg = sample_random_message(MSG_LEN)

    enc_reg = encode_message(replace_bigrams(msg, bigram_list), basic_codebook)
    enc_opt = encode_regular_bigram_optimized(msg)

    t_reg = count_bit_flips(enc_reg)
    t_opt = count_bit_flips(enc_opt)

    reg_transitions.append(t_reg)
    opt_transitions.append(t_opt)

    reg_bits.append(len(enc_reg))
    opt_bits.append(len(enc_opt))
    orig_chars.append(len(msg))

    print(f"Trial{ti+1}: reg_bpc={len(enc_reg)/len(msg):.3f}, opt_bpc={len(enc_opt)/len(msg):.3f}")

print(f"Mean bpc (reg,opt): {np.mean(np.array(reg_bits)/np.array(orig_chars)):.4f}, "
      f"{np.mean(np.array(opt_bits)/np.array(orig_chars)):.4f}")
print(f"Avg transitions (reg,opt): {np.mean(reg_transitions):.2f}, {np.mean(opt_transitions):.2f}, "
      f"reduction={(np.mean(reg_transitions)-np.mean(opt_transitions))/np.mean(reg_transitions)*100:.2f}%")
# Out:
# Initial flip-cost: 6480419.00
#   pass 1: accepted swap at prefix '', new cost=6468382.00
#   pass 1: accepted swap at prefix '0', new cost=6365116.00
#   pass 1: accepted swap at prefix '00', new cost=6333716.00
#   pass 1: accepted swap at prefix '000', new cost=6330136.00
#   pass 1: accepted swap at prefix '0000', new cost=6329148.00
#   pass 1: accepted swap at prefix '00000', new cost=6328798.00
#   pass 1: accepted swap at prefix '000000110', new cost=6328568.00
#   pass 1: accepted swap at prefix '0000001100', new cost=6328566.00
#   pass 1: accepted swap at prefix '00010', new cost=6328106.00
#   pass 1: accepted swap at prefix '000100', new cost=6327984.00
#   pass 1: accepted swap at prefix '000100010', new cost=6326646.00
#   pass 1: accepted swap at prefix '0001010', new cost=6322712.00
#   pass 1: accepted swap at prefix '00010101', new cost=6320888.00
#   pass 1: accepted swap at prefix '0010', new cost=6319220.00
#   pass 1: accepted swap at prefix '00100', new cost=6318986.00
#   pass 1: accepted swap at prefix '001000', new cost=6318790.00
#   pass 1: accepted swap at prefix '0010000', new cost=6318748.00
#   pass 1: accepted swap at prefix '001001', new cost=6310184.00
#   pass 1: accepted swap at prefix '0010110', new cost=6308814.00
#   pass 1: accepted swap at prefix '0011010', new cost=6308744.00
#   pass 1: accepted swap at prefix '00110101', new cost=6307996.00
#   pass 1: accepted swap at prefix '001101010', new cost=6307010.00
#   pass 1: accepted swap at prefix '00110111', new cost=6306240.00
#   pass 1: accepted swap at prefix '0011011110', new cost=6305256.00
#   pass 1: accepted swap at prefix '0011011111', new cost=6305184.00
#   pass 1: accepted swap at prefix '00110111111', new cost=6305042.00
#   pass 1: accepted swap at prefix '0011110', new cost=6305004.00
#   pass 1: accepted swap at prefix '0011111', new cost=6303142.00
#   pass 1: accepted swap at prefix '001111111', new cost=6302490.00
#   pass 1: accepted swap at prefix '010', new cost=6299426.00
#   pass 1: accepted swap at prefix '0100', new cost=6297946.00
#   pass 1: accepted swap at prefix '01000', new cost=6296990.00
#   pass 1: accepted swap at prefix '010000', new cost=6296904.00
#   pass 1: accepted swap at prefix '0100000', new cost=6295984.00
#   pass 1: accepted swap at prefix '0100001', new cost=6294142.00
#   pass 1: accepted swap at prefix '010000110', new cost=6294132.00
#   pass 1: accepted swap at prefix '0100001101', new cost=6294024.00
#   pass 1: accepted swap at prefix '010011', new cost=6293974.00
#   pass 1: accepted swap at prefix '0100110', new cost=6293944.00
#   pass 1: accepted swap at prefix '01001101', new cost=6292444.00
#   pass 1: accepted swap at prefix '01010', new cost=6282534.00
#   pass 1: accepted swap at prefix '0101111', new cost=6279526.00
#   pass 1: accepted swap at prefix '01011110', new cost=6279518.00
#   pass 1: accepted swap at prefix '010111100', new cost=6279066.00
#   pass 1: accepted swap at prefix '0101111000', new cost=6279062.00
#   pass 1: accepted swap at prefix '010111100010', new cost=6278870.00
#   pass 1: accepted swap at prefix '0110', new cost=6277758.00
#   pass 1: accepted swap at prefix '011010', new cost=6275154.00
#   pass 1: accepted swap at prefix '0110110', new cost=6273342.00
#   pass 1: accepted swap at prefix '01101110', new cost=6272706.00
#   pass 1: accepted swap at prefix '011011110', new cost=6272688.00
#   pass 1: accepted swap at prefix '01110', new cost=6272292.00
#   pass 1: accepted swap at prefix '011100', new cost=6270932.00
#   pass 1: accepted swap at prefix '0111100', new cost=6270860.00
#   pass 1: accepted swap at prefix '01111000', new cost=6270814.00
#   pass 1: accepted swap at prefix '10', new cost=6259876.00
#   pass 1: accepted swap at prefix '100', new cost=6256946.00
#   pass 1: accepted swap at prefix '1000', new cost=6255996.00
#   pass 1: accepted swap at prefix '10000', new cost=6255772.00
#   pass 1: accepted swap at prefix '100000', new cost=6255756.00
#   pass 1: accepted swap at prefix '100000010', new cost=6254906.00
#   pass 1: accepted swap at prefix '100000011', new cost=6254488.00
#   pass 1: accepted swap at prefix '1000110', new cost=6253964.00
#   pass 1: accepted swap at prefix '100011110', new cost=6253790.00
#   pass 1: accepted swap at prefix '1000111111', new cost=6253774.00
#   pass 1: accepted swap at prefix '10010', new cost=6253324.00
#   pass 1: accepted swap at prefix '100100', new cost=6253302.00
#   pass 1: accepted swap at prefix '1001001', new cost=6251698.00
#   pass 1: accepted swap at prefix '100100110', new cost=6251676.00
#   pass 1: accepted swap at prefix '10010011010', new cost=6251672.00
#   pass 1: accepted swap at prefix '1001011', new cost=6250862.00
#   pass 1: accepted swap at prefix '1001101', new cost=6249764.00
#   pass 1: accepted swap at prefix '100110110', new cost=6249310.00
#   pass 1: accepted swap at prefix '100111', new cost=6247528.00
#   pass 1: accepted swap at prefix '1010', new cost=6244318.00
#   pass 1: accepted swap at prefix '101011', new cost=6242366.00
#   pass 1: accepted swap at prefix '10110', new cost=6241966.00
#   pass 1: accepted swap at prefix '101100', new cost=6241870.00
#   pass 1: accepted swap at prefix '10110011', new cost=6241482.00
#   pass 1: accepted swap at prefix '1011011', new cost=6238724.00
#   pass 1: accepted swap at prefix '10110111', new cost=6238630.00
#   pass 1: accepted swap at prefix '110', new cost=6236710.00
#   pass 1: accepted swap at prefix '1100', new cost=6235694.00
#   pass 1: accepted swap at prefix '11000', new cost=6235420.00
#   pass 1: accepted swap at prefix '1100010', new cost=6234792.00
#   pass 1: accepted swap at prefix '11000111', new cost=6234514.00
#   pass 1: accepted swap at prefix '110011', new cost=6234148.00
#   pass 1: accepted swap at prefix '1100111', new cost=6231266.00
#   pass 1: accepted swap at prefix '11011101', new cost=6230400.00
#   pass 1: accepted swap at prefix '11101110', new cost=6230120.00
#   pass 1: accepted swap at prefix '1110111010', new cost=6230112.00
#   pass 1: accepted swap at prefix '11101110100', new cost=6230090.00
#   pass 1: accepted swap at prefix '11110', new cost=6229978.00
#   pass 1: accepted swap at prefix '111100', new cost=6229496.00
#   pass 1: accepted swap at prefix '111101', new cost=6229076.00
#   pass 1: accepted swap at prefix '11111', new cost=6221706.00
#   pass 1: accepted swap at prefix '1111111', new cost=6219948.00
#   pass 2: accepted swap at prefix '1010101', new cost=6219452.00
#   pass 2: accepted swap at prefix '10101111111', new cost=6219308.00
#   pass 2: accepted swap at prefix '1011010', new cost=6219294.00
#   pass 2: accepted swap at prefix '10110100', new cost=6217170.00
#   pass 2: accepted swap at prefix '10110111110', new cost=6217168.00
#   pass 2: accepted swap at prefix '10110111111000', new cost=6217130.00
#   pass 2: accepted swap at prefix '10110111111001', new cost=6217124.00
#   pass 2: accepted swap at prefix '10110111111010', new cost=6217120.00
#   pass 2: accepted swap at prefix '101101111111', new cost=6217104.00
#   pass 2: accepted swap at prefix '10110010', new cost=6216472.00
#   pass 2: accepted swap at prefix '1011001111', new cost=6216312.00
#   pass 2: accepted swap at prefix '100101010', new cost=6215440.00
#   pass 2: accepted swap at prefix '100101011', new cost=6215378.00
#   pass 2: accepted swap at prefix '100100110101', new cost=6215330.00
#   pass 2: accepted swap at prefix '10010011010001', new cost=6215326.00
#   pass 2: accepted swap at prefix '10010011000000', new cost=6215292.00
#   pass 2: accepted swap at prefix '10010011000001', new cost=6215238.00
#   pass 2: accepted swap at prefix '1001001100111', new cost=6215184.00
#   pass 2: accepted swap at prefix '10010011111', new cost=6215030.00
#   pass 2: accepted swap at prefix '1001000', new cost=6212208.00
#   pass 2: accepted swap at prefix '1001101101', new cost=6212056.00
#   pass 2: accepted swap at prefix '1001101110', new cost=6212054.00
#   pass 2: accepted swap at prefix '100010', new cost=6212032.00
#   pass 2: accepted swap at prefix '10001100', new cost=6212024.00
#   pass 2: accepted swap at prefix '10001110', new cost=6211518.00
#   pass 2: accepted swap at prefix '10001111010', new cost=6211370.00
#   pass 2: accepted swap at prefix '100011111010', new cost=6211368.00
#   pass 2: accepted swap at prefix '1000111110101', new cost=6211312.00
#   pass 2: accepted swap at prefix '10001111101010', new cost=6211282.00
#   pass 2: accepted swap at prefix '1000111110110', new cost=6211256.00
#   pass 2: accepted swap at prefix '1000111110111', new cost=6211230.00
#   pass 2: accepted swap at prefix '100001', new cost=6207550.00
#   pass 2: accepted swap at prefix '1000000101', new cost=6207434.00
#   pass 2: accepted swap at prefix '110100', new cost=6207278.00
#   pass 2: accepted swap at prefix '1101000', new cost=6207258.00
#   pass 2: accepted swap at prefix '11010000', new cost=6206960.00
#   pass 2: accepted swap at prefix '11010001', new cost=6206832.00
#   pass 2: accepted swap at prefix '110100010', new cost=6206522.00
#   pass 2: accepted swap at prefix '11010010', new cost=6202480.00
#   pass 2: accepted swap at prefix '110111011010', new cost=6202410.00
#   pass 2: accepted swap at prefix '110111110', new cost=6202404.00
#   pass 2: accepted swap at prefix '1101111100', new cost=6202366.00
#   pass 2: accepted swap at prefix '1101111101', new cost=6202290.00
#   pass 2: accepted swap at prefix '110111111', new cost=6201838.00
#   pass 2: accepted swap at prefix '11000100', new cost=6200712.00
#   pass 2: accepted swap at prefix '11000110', new cost=6200700.00
#   pass 2: accepted swap at prefix '110001100', new cost=6199970.00
#   pass 2: accepted swap at prefix '11000110011', new cost=6199654.00
#   pass 2: accepted swap at prefix '110000100', new cost=6199636.00
#   pass 2: accepted swap at prefix '111010', new cost=6199440.00
#   pass 2: accepted swap at prefix '1110100', new cost=6196914.00
#   pass 2: accepted swap at prefix '11101010', new cost=6196878.00
#   pass 2: accepted swap at prefix '1110110', new cost=6193608.00
#   pass 2: accepted swap at prefix '11101110101101', new cost=6193582.00
#   pass 2: accepted swap at prefix '1110111010111', new cost=6193448.00
#   pass 2: accepted swap at prefix '1110111111', new cost=6193436.00
#   pass 2: accepted swap at prefix '1111110', new cost=6193404.00
#   pass 2: accepted swap at prefix '010101010', new cost=6193264.00
#   pass 2: accepted swap at prefix '01010101101', new cost=6193186.00
#   pass 2: accepted swap at prefix '0101010111', new cost=6192852.00
#   pass 2: accepted swap at prefix '0101011', new cost=6190598.00
#   pass 2: accepted swap at prefix '01011101', new cost=6189638.00
#   pass 2: accepted swap at prefix '0101111010', new cost=6189056.00
#   pass 2: accepted swap at prefix '01011110000', new cost=6189054.00
#   pass 2: accepted swap at prefix '010111100000', new cost=6188880.00
#   pass 2: accepted swap at prefix '010111100001', new cost=6188806.00
#   pass 2: accepted swap at prefix '010010', new cost=6187386.00
#   pass 2: accepted swap at prefix '0100110111', new cost=6186876.00
#   pass 2: accepted swap at prefix '010011001100', new cost=6186832.00
#   pass 2: accepted swap at prefix '010001', new cost=6185712.00
#   pass 2: accepted swap at prefix '010000110010000', new cost=6185706.00
#   pass 2: accepted swap at prefix '01000011001011', new cost=6185702.00
#   pass 2: accepted swap at prefix '010000110011', new cost=6185654.00
#   pass 2: accepted swap at prefix '010000111', new cost=6184450.00
#   pass 2: accepted swap at prefix '011010110', new cost=6183172.00
#   pass 2: accepted swap at prefix '0110101110', new cost=6183166.00
#   pass 2: accepted swap at prefix '01101011100', new cost=6183022.00
#   pass 2: accepted swap at prefix '01101011101', new cost=6182976.00
#   pass 2: accepted swap at prefix '0110111010', new cost=6182678.00
#   pass 2: accepted swap at prefix '0110111011', new cost=6182044.00
#   pass 2: accepted swap at prefix '0110111110', new cost=6182034.00
#   pass 2: accepted swap at prefix '01101111100', new cost=6181632.00
#   pass 2: accepted swap at prefix '011011111000', new cost=6181630.00
#   pass 2: accepted swap at prefix '01100', new cost=6181330.00
#   pass 2: accepted swap at prefix '011000', new cost=6181282.00
#   pass 2: accepted swap at prefix '01110101', new cost=6178716.00
#   pass 2: accepted swap at prefix '0111000', new cost=6178484.00
#   pass 2: accepted swap at prefix '011110001101', new cost=6178446.00
#   pass 2: accepted swap at prefix '0111100011111101', new cost=6178444.00
#   pass 2: accepted swap at prefix '011110001111111', new cost=6178438.00
#   pass 2: accepted swap at prefix '011110000', new cost=6178098.00
#   pass 2: accepted swap at prefix '0111110', new cost=6175144.00
#   pass 2: accepted swap at prefix '01111110', new cost=6175124.00
#   pass 2: accepted swap at prefix '011111100', new cost=6175118.00
#   pass 2: accepted swap at prefix '0111111000', new cost=6175114.00
#   pass 2: accepted swap at prefix '0111111001', new cost=6174768.00
#   pass 2: accepted swap at prefix '0111111010', new cost=6174648.00
#   pass 2: accepted swap at prefix '0111111011', new cost=6174610.00
#   pass 2: accepted swap at prefix '0111111110', new cost=6173824.00
#   pass 2: accepted swap at prefix '01111111110', new cost=6173270.00
#   pass 2: accepted swap at prefix '011111111110', new cost=6173268.00
#   pass 2: accepted swap at prefix '0111111111100', new cost=6173228.00
#   pass 2: accepted swap at prefix '01111111111010', new cost=6173150.00
#   pass 2: accepted swap at prefix '0010111', new cost=6172798.00
#   pass 2: accepted swap at prefix '00100111', new cost=6171674.00
#   pass 2: accepted swap at prefix '0010001011', new cost=6171554.00
#   pass 2: accepted swap at prefix '00100011110', new cost=6171078.00
#   pass 2: accepted swap at prefix '00100011111', new cost=6171018.00
#   pass 2: accepted swap at prefix '00100000', new cost=6169486.00
#   pass 2: accepted swap at prefix '0011010101', new cost=6169482.00
#   pass 2: accepted swap at prefix '001101111111100', new cost=6169462.00
#   pass 2: accepted swap at prefix '0011101011', new cost=6169106.00
#   pass 2: accepted swap at prefix '001110111', new cost=6169102.00
#   pass 2: accepted swap at prefix '00111111010', new cost=6169100.00
#   pass 2: accepted swap at prefix '0001010110', new cost=6168614.00
#   pass 2: accepted swap at prefix '0001010111', new cost=6168162.00
#   pass 2: accepted swap at prefix '00010110', new cost=6165576.00
#   pass 2: accepted swap at prefix '000100101', new cost=6165548.00
#   pass 2: accepted swap at prefix '000100111', new cost=6164876.00
#   pass 2: accepted swap at prefix '000100011', new cost=6164136.00
#   pass 2: accepted swap at prefix '00011', new cost=6155064.00
#   pass 2: accepted swap at prefix '00001111', new cost=6154950.00
#   pass 2: accepted swap at prefix '0000011101', new cost=6154582.00
#   pass 2: accepted swap at prefix '000001111', new cost=6154048.00
#   pass 2: accepted swap at prefix '000000110011111', new cost=6154034.00
#   pass 2: accepted swap at prefix '000000110001', new cost=6153986.00
#   pass 3: accepted swap at prefix '10101010', new cost=6153968.00
#   pass 3: accepted swap at prefix '101010101', new cost=6153950.00
#   pass 3: accepted swap at prefix '1010101011', new cost=6153898.00
#   pass 3: accepted swap at prefix '101011111111', new cost=6153890.00
#   pass 3: accepted swap at prefix '1011010011', new cost=6153540.00
#   pass 3: accepted swap at prefix '1011011111001', new cost=6153538.00
#   pass 3: accepted swap at prefix '1011011111111', new cost=6153506.00
#   pass 3: accepted swap at prefix '101100101', new cost=6153240.00
#   pass 3: accepted swap at prefix '100101010100010', new cost=6153222.00
#   pass 3: accepted swap at prefix '1001010101001', new cost=6153210.00
#   pass 3: accepted swap at prefix '1001010101011', new cost=6153146.00
#   pass 3: accepted swap at prefix '10010101011001', new cost=6153118.00
#   pass 3: accepted swap at prefix '1001010101101', new cost=6153106.00
#   pass 3: accepted swap at prefix '100101010111', new cost=6153030.00
#   pass 3: accepted swap at prefix '100100110100010', new cost=6153026.00
#   pass 3: accepted swap at prefix '100100110000001', new cost=6153018.00
#   pass 3: accepted swap at prefix '10010011001111', new cost=6152994.00
#   pass 3: accepted swap at prefix '100100111111', new cost=6152824.00
#   pass 3: accepted swap at prefix '1000101', new cost=6152300.00
#   pass 3: accepted swap at prefix '1000110010', new cost=6152288.00
#   pass 3: accepted swap at prefix '1000110001', new cost=6152102.00
#   pass 3: accepted swap at prefix '100011100', new cost=6151488.00
#   pass 3: accepted swap at prefix '100011111010001', new cost=6151482.00
#   pass 3: accepted swap at prefix '100011111011101', new cost=6151460.00
#   pass 3: accepted swap at prefix '10000001010', new cost=6151452.00
#   pass 3: accepted swap at prefix '100000010100', new cost=6151422.00
#   pass 3: accepted swap at prefix '1000000101011', new cost=6151376.00
#   pass 3: accepted swap at prefix '110100111', new cost=6150596.00
#   pass 3: accepted swap at prefix '1101000100', new cost=6150592.00
#   pass 3: accepted swap at prefix '11010001000', new cost=6150576.00
#   pass 3: accepted swap at prefix '11010000111', new cost=6150494.00
#   pass 3: accepted swap at prefix '11011101101001', new cost=6150436.00
#   pass 3: accepted swap at prefix '11011111011', new cost=6150156.00
#   pass 3: accepted swap at prefix '11011111001', new cost=6150096.00
#   pass 3: accepted swap at prefix '11011111111', new cost=6149950.00
#   pass 3: accepted swap at prefix '1100010010', new cost=6149940.00
#   pass 3: accepted swap at prefix '11000110111', new cost=6149468.00
#   pass 3: accepted swap at prefix '1100011001111', new cost=6149462.00
#   pass 3: accepted swap at prefix '1100001001101', new cost=6149416.00
#   pass 3: accepted swap at prefix '111010101010', new cost=6149404.00
#   pass 3: accepted swap at prefix '11101010110', new cost=6149254.00
#   pass 3: accepted swap at prefix '1110101011100', new cost=6149198.00
#   pass 3: accepted swap at prefix '111010101111', new cost=6149158.00
#   pass 3: accepted swap at prefix '1110101000', new cost=6148914.00
#   pass 3: accepted swap at prefix '11101011', new cost=6148464.00
#   pass 3: accepted swap at prefix '111010011', new cost=6148294.00
#   pass 3: accepted swap at prefix '11101101', new cost=6147484.00
#   pass 3: accepted swap at prefix '11101111111010', new cost=6147464.00
#   pass 3: accepted swap at prefix '01010101010', new cost=6147462.00
#   pass 3: accepted swap at prefix '010101010101', new cost=6147378.00
#   pass 3: accepted swap at prefix '010101010111', new cost=6147360.00
#   pass 3: accepted swap at prefix '01010101101110', new cost=6147358.00
#   pass 3: accepted swap at prefix '01010101101111', new cost=6147348.00
#   pass 3: accepted swap at prefix '0101011110110', new cost=6147318.00
#   pass 3: accepted swap at prefix '0101011111', new cost=6146942.00
#   pass 3: accepted swap at prefix '010111101011', new cost=6146868.00
#   pass 3: accepted swap at prefix '010111100001111', new cost=6146844.00
#   pass 3: accepted swap at prefix '0101111000001011', new cost=6146836.00
#   pass 3: accepted swap at prefix '01011110000011', new cost=6146810.00
#   pass 3: accepted swap at prefix '0100100', new cost=6146752.00
#   pass 3: accepted swap at prefix '01001000', new cost=6145896.00
#   pass 3: accepted swap at prefix '010010001', new cost=6145698.00
#   pass 3: accepted swap at prefix '0100100010', new cost=6145370.00
#   pass 3: accepted swap at prefix '01001101111', new cost=6145254.00
#   pass 3: accepted swap at prefix '0100010', new cost=6145214.00
#   pass 3: accepted swap at prefix '01000100', new cost=6143412.00
#   pass 3: accepted swap at prefix '010001001', new cost=6143008.00
#   pass 3: accepted swap at prefix '0100001111', new cost=6142444.00
#   pass 3: accepted swap at prefix '01101011100100', new cost=6142388.00
#   pass 3: accepted swap at prefix '011010111001100', new cost=6142374.00
#   pass 3: accepted swap at prefix '0110101110011011', new cost=6142372.00
#   pass 3: accepted swap at prefix '011011101011', new cost=6142348.00
#   pass 3: accepted swap at prefix '011011111010', new cost=6142160.00
#   pass 3: accepted swap at prefix '01101111100010', new cost=6142124.00
#   pass 3: accepted swap at prefix '0110111110000', new cost=6142078.00
#   pass 3: accepted swap at prefix '01100010', new cost=6142060.00
#   pass 3: accepted swap at prefix '011000101', new cost=6141730.00
#   pass 3: accepted swap at prefix '011000011', new cost=6140905.00
#   pass 3: accepted swap at prefix '011101011100', new cost=6140833.00
#   pass 3: accepted swap at prefix '011101011101111', new cost=6140811.00
#   pass 3: accepted swap at prefix '011101011111', new cost=6140727.00
#   pass 3: accepted swap at prefix '01110000', new cost=6140713.00
#   pass 3: accepted swap at prefix '011100001', new cost=6139367.00
#   pass 3: accepted swap at prefix '01111000110100', new cost=6139311.00
#   pass 3: accepted swap at prefix '01111000011', new cost=6139067.00
#   pass 3: accepted swap at prefix '011111100110', new cost=6138909.00
#   pass 3: accepted swap at prefix '011111100011', new cost=6138869.00
#   pass 3: accepted swap at prefix '01111110000', new cost=6138667.00
#   pass 3: accepted swap at prefix '011111111011100', new cost=6138663.00
#   pass 3: accepted swap at prefix '011111111011101', new cost=6138651.00
#   pass 3: accepted swap at prefix '01111111111011', new cost=6138629.00
#   pass 3: accepted swap at prefix '011111111110011', new cost=6138587.00
#   pass 3: accepted swap at prefix '00101110', new cost=6138555.00
#   pass 3: accepted swap at prefix '001011100', new cost=6137411.00
#   pass 3: accepted swap at prefix '001011101', new cost=6137381.00
#   pass 3: accepted swap at prefix '00100111101', new cost=6137299.00
#   pass 3: accepted swap at prefix '00100111110', new cost=6136921.00
#   pass 3: accepted swap at prefix '00100010111', new cost=6136513.00
#   pass 3: accepted swap at prefix '0010001111011', new cost=6136483.00
#   pass 3: accepted swap at prefix '001000001', new cost=6136141.00
#   pass 3: accepted swap at prefix '00111010111', new cost=6135679.00
#   pass 3: accepted swap at prefix '00111011110', new cost=6135677.00
#   pass 3: accepted swap at prefix '001110111101', new cost=6135661.00
#   pass 3: accepted swap at prefix '00111011111', new cost=6135383.00
#   pass 3: accepted swap at prefix '00111111010110001101', new cost=6135381.00
#   pass 3: accepted swap at prefix '0011111101011011', new cost=6135377.00
#   pass 3: accepted swap at prefix '0011111101011110', new cost=6135365.00
#   pass 3: accepted swap at prefix '0011111101000', new cost=6135245.00
#   pass 3: accepted swap at prefix '00010101101', new cost=6135221.00
#   pass 3: accepted swap at prefix '000101011110', new cost=6135195.00
#   pass 3: accepted swap at prefix '0001011010', new cost=6134435.00
#   pass 3: accepted swap at prefix '0001011011', new cost=6133593.00
#   pass 3: accepted swap at prefix '00010010100', new cost=6133589.00
#   pass 3: accepted swap at prefix '000100101001', new cost=6133499.00
#   pass 3: accepted swap at prefix '0001001110', new cost=6133111.00
#   pass 3: accepted swap at prefix '0001000111', new cost=6132273.00
#   pass 3: accepted swap at prefix '000110', new cost=6131387.00
#   pass 3: accepted swap at prefix '000011111000000', new cost=6131335.00
#   pass 3: accepted swap at prefix '000011111000010', new cost=6131311.00
#   pass 3: accepted swap at prefix '000011111000011', new cost=6131299.00
#   pass 3: accepted swap at prefix '00001111100101', new cost=6131283.00
#   pass 3: accepted swap at prefix '000011111110', new cost=6131183.00
#   pass 3: accepted swap at prefix '0000111111110', new cost=6131089.00
#   pass 3: accepted swap at prefix '0000011101100', new cost=6131079.00
#   pass 3: accepted swap at prefix '000001110111', new cost=6130933.00
#   pass 3: accepted swap at prefix '0000011110', new cost=6130421.00
#   pass 3: accepted swap at prefix '000000110001101', new cost=6130415.00
#   pass 4: accepted swap at prefix '10101010110010', new cost=6130399.00
#   pass 4: accepted swap at prefix '1010101001', new cost=6129845.00
#   pass 4: accepted swap at prefix '101101111100110', new cost=6129835.00
#   pass 4: accepted swap at prefix '101101111111111', new cost=6129827.00
#   pass 4: accepted swap at prefix '1011001011', new cost=6129331.00
#   pass 4: accepted swap at prefix '10001011', new cost=6129159.00
#   pass 4: accepted swap at prefix '100011001010', new cost=6129049.00
#   pass 4: accepted swap at prefix '10001100011000', new cost=6129047.00
#   pass 4: accepted swap at prefix '10001100011001', new cost=6129041.00
#   pass 4: accepted swap at prefix '10001100011010', new cost=6129035.00
#   pass 4: accepted swap at prefix '100011000111', new cost=6128933.00
#   pass 4: accepted swap at prefix '1000111001', new cost=6128813.00
#   pass 4: accepted swap at prefix '10000001010111', new cost=6128805.00
#   pass 4: accepted swap at prefix '1000000101000', new cost=6128729.00
#   pass 4: accepted swap at prefix '1101001111', new cost=6128455.00
#   pass 4: accepted swap at prefix '1101000100111', new cost=6128423.00
#   pass 4: accepted swap at prefix '110111110110000', new cost=6128415.00
#   pass 4: accepted swap at prefix '110111110110001', new cost=6128409.00
#   pass 4: accepted swap at prefix '110111110010', new cost=6128317.00
#   pass 4: accepted swap at prefix '1101111111111', new cost=6128277.00
#   pass 4: accepted swap at prefix '110001001010', new cost=6128249.00
#   pass 4: accepted swap at prefix '11101010101001', new cost=6128221.00
#   pass 4: accepted swap at prefix '111010101101', new cost=6128095.00
#   pass 4: accepted swap at prefix '111010100011', new cost=6128065.00
#   pass 4: accepted swap at prefix '1110100111', new cost=6127747.00
#   pass 4: accepted swap at prefix '111011111110101', new cost=6127717.00
#   pass 4: accepted swap at prefix '0101010101011', new cost=6127625.00
#   pass 4: accepted swap at prefix '01010101011111', new cost=6127617.00
#   pass 4: accepted swap at prefix '01010111110', new cost=6127529.00
#   pass 4: accepted swap at prefix '0101111000011111', new cost=6127521.00
#   pass 4: accepted swap at prefix '010010011', new cost=6127257.00
#   pass 4: accepted swap at prefix '010010001010', new cost=6127169.00
#   pass 4: accepted swap at prefix '0100110111111', new cost=6127117.00
#   pass 4: accepted swap at prefix '010001010110111', new cost=6127109.00
#   pass 4: accepted swap at prefix '010001010111', new cost=6126961.00
#   pass 4: accepted swap at prefix '01000011110001', new cost=6126919.00
#   pass 4: accepted swap at prefix '0110111010111110', new cost=6126915.00
#   pass 4: accepted swap at prefix '0110111010111111', new cost=6126907.00
#   pass 4: accepted swap at prefix '01100001110', new cost=6126655.00
#   pass 4: accepted swap at prefix '01110101110010', new cost=6126603.00
#   pass 4: accepted swap at prefix '01110101110011', new cost=6126535.00
#   pass 4: accepted swap at prefix '01110101111111', new cost=6126507.00
#   pass 4: accepted swap at prefix '0111000000', new cost=6126497.00
#   pass 4: accepted swap at prefix '01110000000', new cost=6126493.00
#   pass 4: accepted swap at prefix '0111000000011', new cost=6126435.00
#   pass 4: accepted swap at prefix '011100000011', new cost=6126287.00
#   pass 4: accepted swap at prefix '011110001101001', new cost=6126277.00
#   pass 4: accepted swap at prefix '01111000011111', new cost=6126207.00
#   pass 4: accepted swap at prefix '0111111001101', new cost=6126199.00
#   pass 4: accepted swap at prefix '0111111000111', new cost=6126119.00
#   pass 4: accepted swap at prefix '011111111110111', new cost=6126109.00
#   pass 4: accepted swap at prefix '0010111010', new cost=6125551.00
#   pass 4: accepted swap at prefix '001001111011110', new cost=6125535.00
#   pass 4: accepted swap at prefix '00100010111101', new cost=6125513.00
#   pass 4: accepted swap at prefix '001000101111100', new cost=6125507.00
#   pass 4: accepted swap at prefix '001000101111101', new cost=6125505.00
#   pass 4: accepted swap at prefix '0010000011', new cost=6125013.00
#   pass 4: accepted swap at prefix '001110111110', new cost=6124907.00
#   pass 4: accepted swap at prefix '000101101110', new cost=6124837.00
#   pass 4: accepted swap at prefix '000101101111', new cost=6124819.00
#   pass 4: accepted swap at prefix '0001001010011', new cost=6124741.00
#   pass 4: accepted swap at prefix '0001001110011', new cost=6124659.00
#   pass 4: accepted swap at prefix '0001100', new cost=6124605.00
#   pass 4: accepted swap at prefix '0000111110000111', new cost=6124595.00
#   pass 4: accepted swap at prefix '000011111001011', new cost=6124569.00
#   pass 4: accepted swap at prefix '0000111111101', new cost=6124563.00
#   pass 4: accepted swap at prefix '00001111111100', new cost=6124559.00
#   pass 4: accepted swap at prefix '000001110110010', new cost=6124525.00
#   pass 4: accepted swap at prefix '00000111101', new cost=6124353.00
#   pass 5: accepted swap at prefix '101010100110', new cost=6124147.00
#   pass 5: accepted swap at prefix '100010111', new cost=6122927.00
#   pass 5: accepted swap at prefix '1000110010101', new cost=6122875.00
#   pass 5: accepted swap at prefix '11011111001011', new cost=6122833.00
#   pass 5: accepted swap at prefix '11000100101001', new cost=6122815.00
#   pass 5: accepted swap at prefix '111010101010011', new cost=6122809.00
#   pass 5: accepted swap at prefix '111010101101001', new cost=6122797.00
#   pass 5: accepted swap at prefix '11101010110101', new cost=6122779.00
#   pass 5: accepted swap at prefix '11101010001110', new cost=6122761.00
#   pass 5: accepted swap at prefix '11101010001111011', new cost=6122753.00
#   pass 5: accepted swap at prefix '1110100111101', new cost=6122711.00
#   pass 5: accepted swap at prefix '11101001111101', new cost=6122677.00
#   pass 5: accepted swap at prefix '1110100111111', new cost=6122653.00
#   pass 5: accepted swap at prefix '01010101010111', new cost=6122633.00
#   pass 5: accepted swap at prefix '011101011100101', new cost=6122589.00
#   pass 5: accepted swap at prefix '01110000001011', new cost=6122569.00
#   pass 5: accepted swap at prefix '01110000001100', new cost=6122561.00
#   pass 5: accepted swap at prefix '0111000000010', new cost=6122553.00
#   pass 5: accepted swap at prefix '0111000000001101', new cost=6122545.00
#   pass 5: accepted swap at prefix '01111110001111', new cost=6122539.00
#   pass 5: accepted swap at prefix '001011101010', new cost=6122537.00
#   pass 5: accepted swap at prefix '0010111010100', new cost=6122485.00
#   pass 5: accepted swap at prefix '0010111010101', new cost=6122385.00
#   pass 5: accepted swap at prefix '00100000110', new cost=6122049.00
#   pass 5: accepted swap at prefix '0011101111100', new cost=6122007.00
#   pass 5: accepted swap at prefix '0001011011100', new cost=6121875.00
#   pass 5: accepted swap at prefix '0001100110', new cost=6121753.00
#   pass 5: accepted swap at prefix '00011001110', new cost=6121749.00
#   pass 5: accepted swap at prefix '000110011100', new cost=6121525.00
#   pass 5: accepted swap at prefix '000110011101', new cost=6121393.00
# Trial1: reg_bpc=4.035, opt_bpc=4.035
# Trial2: reg_bpc=4.034, opt_bpc=4.034
# Trial3: reg_bpc=4.134, opt_bpc=4.134
# Trial4: reg_bpc=3.953, opt_bpc=3.953
# Trial5: reg_bpc=3.925, opt_bpc=3.925
# Trial6: reg_bpc=3.995, opt_bpc=3.995
# Trial7: reg_bpc=4.028, opt_bpc=4.028
# Trial8: reg_bpc=5.144, opt_bpc=5.144
# Trial9: reg_bpc=3.971, opt_bpc=3.971
# Trial10: reg_bpc=4.131, opt_bpc=4.131
# Trial11: reg_bpc=4.096, opt_bpc=4.096
# Trial12: reg_bpc=3.948, opt_bpc=3.948
# Trial13: reg_bpc=3.906, opt_bpc=3.906
# Trial14: reg_bpc=3.996, opt_bpc=3.996
# Trial15: reg_bpc=3.994, opt_bpc=3.994
# Trial16: reg_bpc=4.133, opt_bpc=4.133
# Trial17: reg_bpc=3.873, opt_bpc=3.873
# Trial18: reg_bpc=3.902, opt_bpc=3.902
# Trial19: reg_bpc=4.050, opt_bpc=4.050
# Trial20: reg_bpc=4.442, opt_bpc=4.442
# Trial21: reg_bpc=3.938, opt_bpc=3.938
# Trial22: reg_bpc=3.928, opt_bpc=3.928
# Trial23: reg_bpc=3.878, opt_bpc=3.878
# Trial24: reg_bpc=3.956, opt_bpc=3.956
# Trial25: reg_bpc=3.976, opt_bpc=3.976
# Trial26: reg_bpc=4.021, opt_bpc=4.021
# Trial27: reg_bpc=4.135, opt_bpc=4.135
# Trial28: reg_bpc=4.170, opt_bpc=4.170
# Trial29: reg_bpc=4.163, opt_bpc=4.163
# Trial30: reg_bpc=4.119, opt_bpc=4.119
# Trial31: reg_bpc=3.994, opt_bpc=3.994
# Trial32: reg_bpc=4.009, opt_bpc=4.009
# Trial33: reg_bpc=4.095, opt_bpc=4.095
# Trial34: reg_bpc=3.992, opt_bpc=3.992
# Trial35: reg_bpc=4.000, opt_bpc=4.000
# Trial36: reg_bpc=3.886, opt_bpc=3.886
# Trial37: reg_bpc=3.963, opt_bpc=3.963
# Trial38: reg_bpc=4.006, opt_bpc=4.006
# Trial39: reg_bpc=4.004, opt_bpc=4.004
# Trial40: reg_bpc=4.132, opt_bpc=4.132
# Trial41: reg_bpc=4.004, opt_bpc=4.004
# Trial42: reg_bpc=3.991, opt_bpc=3.991
# Trial43: reg_bpc=4.077, opt_bpc=4.077
# Trial44: reg_bpc=4.138, opt_bpc=4.138
# Trial45: reg_bpc=4.012, opt_bpc=4.012
# Trial46: reg_bpc=4.011, opt_bpc=4.011
# Trial47: reg_bpc=4.117, opt_bpc=4.117
# Trial48: reg_bpc=3.928, opt_bpc=3.928
# Trial49: reg_bpc=4.025, opt_bpc=4.025
# Trial50: reg_bpc=3.945, opt_bpc=3.945
# Trial51: reg_bpc=4.022, opt_bpc=4.022
# Trial52: reg_bpc=4.112, opt_bpc=4.112
# Trial53: reg_bpc=3.930, opt_bpc=3.930
# Trial54: reg_bpc=4.028, opt_bpc=4.028
# Trial55: reg_bpc=4.094, opt_bpc=4.094
# Trial56: reg_bpc=3.945, opt_bpc=3.945
# Trial57: reg_bpc=3.998, opt_bpc=3.998
# Trial58: reg_bpc=4.048, opt_bpc=4.048
# Trial59: reg_bpc=4.035, opt_bpc=4.035
# Trial60: reg_bpc=4.015, opt_bpc=4.015
# Trial61: reg_bpc=3.984, opt_bpc=3.984
# Trial62: reg_bpc=3.980, opt_bpc=3.980
# Trial63: reg_bpc=4.020, opt_bpc=4.020
# Trial64: reg_bpc=3.899, opt_bpc=3.899
# Trial65: reg_bpc=4.094, opt_bpc=4.094
# Trial66: reg_bpc=3.914, opt_bpc=3.914
# Trial67: reg_bpc=4.073, opt_bpc=4.073
# Trial68: reg_bpc=4.110, opt_bpc=4.110
# Trial69: reg_bpc=4.046, opt_bpc=4.046
# Trial70: reg_bpc=4.010, opt_bpc=4.010
# Trial71: reg_bpc=4.036, opt_bpc=4.036
# Trial72: reg_bpc=4.086, opt_bpc=4.086
# Trial73: reg_bpc=4.163, opt_bpc=4.163
# Trial74: reg_bpc=4.011, opt_bpc=4.011
# Trial75: reg_bpc=4.107, opt_bpc=4.107
# Trial76: reg_bpc=4.035, opt_bpc=4.035
# Trial77: reg_bpc=3.967, opt_bpc=3.967
# Trial78: reg_bpc=3.971, opt_bpc=3.971
# Trial79: reg_bpc=4.074, opt_bpc=4.074
# Trial80: reg_bpc=4.190, opt_bpc=4.190
# Trial81: reg_bpc=4.018, opt_bpc=4.018
# Trial82: reg_bpc=3.976, opt_bpc=3.976
# Trial83: reg_bpc=3.997, opt_bpc=3.997
# Trial84: reg_bpc=4.161, opt_bpc=4.161
# Trial85: reg_bpc=4.084, opt_bpc=4.084
# Trial86: reg_bpc=4.152, opt_bpc=4.152
# Trial87: reg_bpc=4.025, opt_bpc=4.025
# Trial88: reg_bpc=4.040, opt_bpc=4.040
# Trial89: reg_bpc=3.911, opt_bpc=3.911
# Trial90: reg_bpc=4.209, opt_bpc=4.209
# Trial91: reg_bpc=4.033, opt_bpc=4.033
# Trial92: reg_bpc=4.076, opt_bpc=4.076
# Trial93: reg_bpc=4.098, opt_bpc=4.098
# Trial94: reg_bpc=4.107, opt_bpc=4.107
# Trial95: reg_bpc=3.971, opt_bpc=3.971
# Trial96: reg_bpc=4.052, opt_bpc=4.052
# Trial97: reg_bpc=4.066, opt_bpc=4.066
# Trial98: reg_bpc=4.106, opt_bpc=4.106
# Trial99: reg_bpc=3.899, opt_bpc=3.899
# Trial100: reg_bpc=4.006, opt_bpc=4.006
# Mean bpc (reg,opt): 4.0429, 4.0429
# Avg transitions (reg,opt): 2019.46, 1909.21, reduction=5.46%

# %% [markdown]
# Very simple idea here: of codes of the same bit length, it maps the highest frequency codes to teh hgihest

# %%
# 1) Compute internal flips for a codeword
def internal_flips(code):
    if not code: 
        return 0
    return sum(1 for i in range(len(code)-1) if code[i] != code[i+1])

# 2) Remap codebook without changing any symbol's code length:
#    For each length L, give the most frequent symbols the codewords
#    with the fewest internal flips.
def remap_codebook_min_internal_flips(codebook, freqs):
    # Group symbols and codewords by length
    len_to_symbols = {}
    len_to_codes = {}
    for sym, code in codebook.items():
        L = len(code)
        len_to_symbols.setdefault(L, []).append(sym)
        len_to_codes.setdefault(L, []).append(code)
    # Build new mapping
    new_cb = {}
    for L in len_to_symbols:
        # Sort symbols by descending frequency
        syms_sorted = sorted(len_to_symbols[L], key=lambda s: freqs.get(s, 0), reverse=True)
        # Sort codes by ascending internal flips (tie-break: fewer 1s to slightly reduce alternations)
        codes_sorted = sorted(
            len_to_codes[L],
            key=lambda c: (internal_flips(c), c.count('1'))
        )
        # Assign best (low-flip) codes to most frequent symbols
        for s, c in zip(syms_sorted, codes_sorted):
            new_cb[s] = c
    return new_cb

# 3) Optional tiny decoder from a codebook (if you don’t rebuild a tree)
def build_decoder_from_codebook(codebook):
    root = {}
    for sym, code in codebook.items():
        node = root
        for ch in code:
            node = node.setdefault(ch, {})
        node['$'] = sym
    return root

def decode_with_decoder(bits, dec):
    out = []
    node = dec
    for b in bits:
        node = node[b]
        if '$' in node:
            out.append(node['$'])
            node = dec
    return "".join(out)
# Build baseline (no variants)
train_text = readfile("WarAndPeace.txt")
K = 10000
bigram_list = top_bigrams(train_text, K)
symbol_stream = replace_bigrams(train_text, bigram_list)
freqs = Counter(symbol_stream)

basic_tree = build_huffman_tree(freqs)
basic_codebook = build_codebook(basic_tree)

# Remap within equal-length groups to minimize internal flips
opt_codebook = remap_codebook_min_internal_flips(basic_codebook, freqs)

# Encode with the optimized codebook (bpc stays identical to baseline)
def encode_regular_bigram_opt(text):
    syms = replace_bigrams(text, bigram_list)
    return encode_message(syms, opt_codebook)

# Optional: decode using the tiny decoder above
opt_decoder = build_decoder_from_codebook(opt_codebook)
def decode_opt(bits):
    return decode_with_decoder(bits, opt_decoder)

# Quick eval
msg = sample_random_message(1000)
enc_reg = encode_message(replace_bigrams(msg, bigram_list), basic_codebook)
enc_opt = encode_regular_bigram_opt(msg)
print("reg_bpc:", len(enc_reg)/len(msg), "opt_bpc:", len(enc_opt)/len(msg))  # should match
print("reg_flips:", count_bit_flips(enc_reg), "opt_flips:", count_bit_flips(enc_opt))
# Out:
# reg_bpc: 3.967 opt_bpc: 3.967
# reg_flips: 1991 opt_flips: 1867

# %%
def find_missing(text, codebook, bigram_list):
    syms = replace_bigrams(text, bigram_list)
    missing = [s for s in syms if s not in codebook]
    return syms, missing

syms, missing = find_missing(msg, basic_codebook, bigram_list)
print("Missing count:", len(missing))
print("First few missing:", [repr(m) for m in missing[:20]])
train_syms = replace_bigrams(train_text, bigram_list)
miss_train = {s for s in set(train_syms) if s not in basic_codebook}
print("Missing in training stream (should be empty):", miss_train)
assert set(opt_codebook.keys()) == set(basic_codebook.keys())
# Out:
# Missing count: 2
# First few missing: ["'8,'", "'6;'"]
# Missing in training stream (should be empty): set()

# %%
def transitions_per_bit(bits):
    if not bits or len(bits) <= 1:
        return 0.0
    flips = sum(1 for i in range(len(bits)-1) if bits[i] != bits[i+1])
    return flips / (len(bits)-1)

def p_uncorrectable_hamming(n, p):
    # Uncorrectable probability for single-error-correcting Hamming over i.i.d. BER p
    return 1.0 - ((1-p)**n + n*p*(1-p)**(n-1))

def hamming_n_candidates(r_min=3, r_max=16, extended=False):
    # Standard Hamming: n = 2^r - 1; Extended (SECDED): n = 2^r
    for r in range(r_min, r_max+1):
        n = (1 << r) if extended else ((1 << r) - 1)
        yield n, r

def best_hamming_n_for(p, epsilon=1e-6, r_min=3, r_max=16, extended=False):
    # Returns the largest (n, r) meeting P_uncorr <= epsilon, or None
    best = None
    for n, r in hamming_n_candidates(r_min, r_max, extended=extended):
        if p_uncorrectable_hamming(n, p) <= epsilon:
            best = (n, r)
    return best

def encode_with_cb(text, codebook, bigram_list):
    syms = replace_bigrams(text, bigram_list)
    return encode_message(syms, codebook)



# compute transition density for each tree
# Assume you already have:
# - basic_codebook (regular Huffman)
# - opt_codebook   (your remapped, flip-minimizing codebook)
# - bigram_list, sample_random_message, encode_message, replace_bigrams

N_SAMPLES = 50
MSG_LEN   = 20000

taus_base = []
taus_opt  = []
for _ in range(N_SAMPLES):
    msg = sample_random_message(MSG_LEN)
    b_base = encode_with_cb(msg, basic_codebook, bigram_list)
    b_opt  = encode_with_cb(msg,  opt_codebook,   bigram_list)
    taus_base.append(transitions_per_bit(b_base))
    taus_opt.append(transitions_per_bit(b_opt))

tau_base = sum(taus_base)/len(taus_base)
tau_opt  = sum(taus_opt)/len(taus_opt)
print(f"avg tau_base={tau_base:.5f}, tau_opt={tau_opt:.5f}, reduction={(tau_base - tau_opt)/tau_base*100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-8e4e6c5b1e29> in <module>
#      42 for _ in range(N_SAMPLES):
#      43     msg = sample_random_message(MSG_LEN)
# ---> 44     b_base = encode_with_cb(msg, basic_codebook, bigram_list)
#      45     b_opt  = encode_with_cb(msg,  opt_codebook,   bigram_list)
#      46     taus_base.append(transitions_per_bit(b_base))
#
# <ipython-input-25-8e4e6c5b1e29> in encode_with_cb(text, codebook, bigram_list)
#      25 def encode_with_cb(text, codebook, bigram_list):
#      26     syms = replace_bigrams(text, bigram_list)
# ---> 27     return encode_message(syms, codebook)
#      28
#      29
#
# <ipython-input-3-f3b83cc539ee> in encode_message(message, codes)
#      60 # encodes a message given a particular codebook
#      61 def encode_message(message, codes):
# ---> 62     encoded_message = "".join(codes[ch] for ch in message) # uses generator expression to create encoded message
#      63     return encoded_message
#      64
#
# <ipython-input-3-f3b83cc539ee> in <genexpr>(.0)
#      60 # encodes a message given a particular codebook
#      61 def encode_message(message, codes):
# ---> 62     encoded_message = "".join(codes[ch] for ch in message) # uses generator expression to create encoded message
#      63     return encoded_message
#      64
#
# KeyError: '8,'

# %% [markdown]
# Sort of stopped working on that here -- was going down a big rabbit hole.
